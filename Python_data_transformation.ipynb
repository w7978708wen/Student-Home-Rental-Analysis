# %% [markdown]
# # Step 1. Import datasets

# %%
import pandas as pd
import numpy as np

applicant_df = pd.read_csv("Simulated applicant dataset - Applicant Dataset.csv")

# Show the first 5 lines
applicant_df.head()
# Out:
#     Age  Entry ID             Gender           City State Province  \
# 0  22.0    400001               Male         City 1     Province 1
# 1  19.0    400002             Female  International  International
# 2   NaN    400003  Prefer not to say         City 3    Province 10
# 3  17.0    400004              Other  International  International
# 4  24.0    400005               Male         City 5     Province 1
#
#    Zip Postcode Application Date Application Status   \
# 0        1234.0       2024-11-01      Offer Accepted
# 1           NaN       2024-11-16      Offer Declined
# 2        2300.0       2023-11-03      Offer Accepted
# 3           NaN       2024-10-05      Offer Declined
# 4        1234.0       2023-01-05      Offer Accepted
#
#   Classification Description Offer Reply Date  ... Room Type offered  \
# 0                       New        2024-11-21  ...       Single Room
# 1                   Returner       2024-11-21  ...         1-Bedroom
# 2                       New        2024-11-24  ...        2-Bedroom
# 3                       New        2024-11-30  ...         5-Bedroom
# 4                   Returner       2024-01-24  ...       Single Room
#
#    Aboriginal/Torres Strait Islander  Course Description  Enrollment Class  \
# 0                                No            Program 1     Undergraduate
# 1                                No            Program 2      Postgraduate
# 2                                NaN           Program 3               PhD
# 3                                No            Program 2               PhD
# 4                                No            Program 2      Postgraduate
#
#        1st Room Preference      2nd Room Preference      3rd Room Preference  \
# 0      Single Room - APT-1      Two Bedroom - APT-3     Five Bedroom - APT-3
# 1  Two Bedroom - College-1      Single Room - APT-1      Single Room - APT-5
# 2  One Bedroom - College-3  Two Bedroom - College-3      Single Room - APT-1
# 3      Single Room - APT-1      Single Room - APT-5  One Bedroom - College-3
# 4  Two Bedroom - College-5  Two Bedroom - College-5      Single Room - APT-5
#
#       4th Room Preference   5th Room Preference   6th Room Preference
# 0  Two Bedroom- College-3  Five Bedroom - APT-1  Five Bedroom - APT-5
# 1                     NaN                   NaN                   NaN
# 2                     NaN                   NaN                   NaN
# 3  Two Bedroom- College-5  Five Bedroom - APT-1                   NaN
# 4                     NaN                   NaN                   NaN
#
# [5 rows x 25 columns]

# %%
capacity_df = pd.read_csv("Simulated student home rental dataset - Capacity.csv")

# Show the first 5 lines
capacity_df.head()
# Out:
#     Full building name Coded name  Capacity
# 0   Amazing Apartment       APT-1       200
# 1  Brilliant Apartment      APT-3       300
# 2  Fantastic Apartment      APT-5       400
# 3        Great College  College-1       300
# 4   Incredible College  College-3       500

# %%
# Import dataset, use skiprows=2 to omit the first 2 rows of text
pricing_df = pd.read_csv("Simulated student home rental dataset - Pricing.csv", skiprows=2)

# Show the first 5 lines
pricing_df.head()
# Out:
#   Room Building    Room Type  Monthly Rent  Monthly Utilities
# 0         APT-1  Single Room          1000                 50
# 1         APT-1    1 Bedroom           950                 50
# 2         APT-1    2 Bedroom           900                 50
# 3         APT-1    5 Bedroom           800                 50
# 4         APT-3  Single Room          2000                100

# %% [markdown]
# # Step 2. Data transformation

# %% [markdown]
# Dataset 1: Applicant

# %%
# Handling missing values
# Check which row has missing values
applicant_df.isnull().sum()

# Replace missing value in Age column with mode
applicant_df['Age'].fillna(applicant_df['Age'].mode()[0], inplace=True)

# Check whether Age column still has missing value
applicant_df.isnull().sum()
# Out:
# /tmp/ipython-input-313187841.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   applicant_df['Age'].fillna(applicant_df['Age'].mode()[0], inplace=True)
# Age                                   0
# Entry ID                              0
# Gender                                0
# City                                  0
# State Province                        0
# Zip Postcode                         10
# Application Date                      0
# Application Status                    0
# Classification Description            0
# Offer Reply Date                      2
# Offer Sent Date                       2
# Apply for Scholarship?                0
# Children accompanied?                 0
# Partner accompanied?                  0
# Location offered                      0
# Room Type offered                     0
# Aboriginal/Torres Strait Islander     1
# Course Description                    0
# Enrollment Class                      0
# 1st Room Preference                   0
# 2nd Room Preference                   0
# 3rd Room Preference                   0
# 4th Room Preference                  15
# 5th Room Preference                  17
# 6th Room Preference                  20
# dtype: int64

# %%
# See how the data frame looks like (first 5 lines)
applicant_df.head()
# Out:
#     Age  Entry ID             Gender           City State Province  \
# 0  22.0    400001               Male         City 1     Province 1
# 1  19.0    400002             Female  International  International
# 2  22.0    400003  Prefer not to say         City 3    Province 10
# 3  17.0    400004              Other  International  International
# 4  24.0    400005               Male         City 5     Province 1
#
#    Zip Postcode Application Date Application Status   \
# 0        1234.0       2024-11-01      Offer Accepted
# 1           NaN       2024-11-16      Offer Declined
# 2        2300.0       2023-11-03      Offer Accepted
# 3           NaN       2024-10-05      Offer Declined
# 4        1234.0       2023-01-05      Offer Accepted
#
#   Classification Description Offer Reply Date  ... Room Type offered  \
# 0                       New        2024-11-21  ...       Single Room
# 1                   Returner       2024-11-21  ...         1-Bedroom
# 2                       New        2024-11-24  ...        2-Bedroom
# 3                       New        2024-11-30  ...         5-Bedroom
# 4                   Returner       2024-01-24  ...       Single Room
#
#    Aboriginal/Torres Strait Islander  Course Description  Enrollment Class  \
# 0                                No            Program 1     Undergraduate
# 1                                No            Program 2      Postgraduate
# 2                                NaN           Program 3               PhD
# 3                                No            Program 2               PhD
# 4                                No            Program 2      Postgraduate
#
#        1st Room Preference      2nd Room Preference      3rd Room Preference  \
# 0      Single Room - APT-1      Two Bedroom - APT-3     Five Bedroom - APT-3
# 1  Two Bedroom - College-1      Single Room - APT-1      Single Room - APT-5
# 2  One Bedroom - College-3  Two Bedroom - College-3      Single Room - APT-1
# 3      Single Room - APT-1      Single Room - APT-5  One Bedroom - College-3
# 4  Two Bedroom - College-5  Two Bedroom - College-5      Single Room - APT-5
#
#       4th Room Preference   5th Room Preference   6th Room Preference
# 0  Two Bedroom- College-3  Five Bedroom - APT-1  Five Bedroom - APT-5
# 1                     NaN                   NaN                   NaN
# 2                     NaN                   NaN                   NaN
# 3  Two Bedroom- College-5  Five Bedroom - APT-1                   NaN
# 4                     NaN                   NaN                   NaN
#
# [5 rows x 25 columns]

# %%
# Remove not useful columns: 4th - 6th room preference columns
# Assigned a new data frame name to keep track of different data frame versions
applicant_df1 = applicant_df.drop(columns=['4th Room Preference','5th Room Preference','6th Room Preference'])

# See how the data frame looks like (first 5 lines)
applicant_df1.head()
# Out:
#     Age  Entry ID             Gender           City State Province  \
# 0  22.0    400001               Male         City 1     Province 1
# 1  19.0    400002             Female  International  International
# 2  22.0    400003  Prefer not to say         City 3    Province 10
# 3  17.0    400004              Other  International  International
# 4  24.0    400005               Male         City 5     Province 1
#
#    Zip Postcode Application Date Application Status   \
# 0        1234.0       2024-11-01      Offer Accepted
# 1           NaN       2024-11-16      Offer Declined
# 2        2300.0       2023-11-03      Offer Accepted
# 3           NaN       2024-10-05      Offer Declined
# 4        1234.0       2023-01-05      Offer Accepted
#
#   Classification Description Offer Reply Date  ... Children accompanied?  \
# 0                       New        2024-11-21  ...                 False
# 1                   Returner       2024-11-21  ...                 False
# 2                       New        2024-11-24  ...                 False
# 3                       New        2024-11-30  ...                 False
# 4                   Returner       2024-01-24  ...                 False
#
#    Partner accompanied?  Location offered  Room Type offered  \
# 0                 False             APT-1        Single Room
# 1                 False             APT-3          1-Bedroom
# 2                 False             APT-5         2-Bedroom
# 3                 False         College-1          5-Bedroom
# 4                 False             APT-3        Single Room
#
#   Aboriginal/Torres Strait Islander Course Description Enrollment Class  \
# 0                               No           Program 1    Undergraduate
# 1                               No           Program 2     Postgraduate
# 2                               NaN          Program 3              PhD
# 3                               No           Program 2              PhD
# 4                               No           Program 2     Postgraduate
#
#        1st Room Preference      2nd Room Preference      3rd Room Preference
# 0      Single Room - APT-1      Two Bedroom - APT-3     Five Bedroom - APT-3
# 1  Two Bedroom - College-1      Single Room - APT-1      Single Room - APT-5
# 2  One Bedroom - College-3  Two Bedroom - College-3      Single Room - APT-1
# 3      Single Room - APT-1      Single Room - APT-5  One Bedroom - College-3
# 4  Two Bedroom - College-5  Two Bedroom - College-5      Single Room - APT-5
#
# [5 rows x 22 columns]

# %%
# Adding a new column with different values using logic
applicant_df1["Student Type"] = applicant_df1["State Province"].apply(lambda x: "International" if x == "International" else "Domestic")


# See how the data frame looks like (first 5 lines)
applicant_df1.head()
# Out:
#     Age  Entry ID             Gender           City State Province  \
# 0  22.0    400001               Male         City 1     Province 1
# 1  19.0    400002             Female  International  International
# 2  22.0    400003  Prefer not to say         City 3    Province 10
# 3  17.0    400004              Other  International  International
# 4  24.0    400005               Male         City 5     Province 1
#
#    Zip Postcode Application Date Application Status   \
# 0        1234.0       2024-11-01      Offer Accepted
# 1           NaN       2024-11-16      Offer Declined
# 2        2300.0       2023-11-03      Offer Accepted
# 3           NaN       2024-10-05      Offer Declined
# 4        1234.0       2023-01-05      Offer Accepted
#
#   Classification Description Offer Reply Date  ... Partner accompanied?  \
# 0                       New        2024-11-21  ...                False
# 1                   Returner       2024-11-21  ...                False
# 2                       New        2024-11-24  ...                False
# 3                       New        2024-11-30  ...                False
# 4                   Returner       2024-01-24  ...                False
#
#    Location offered  Room Type offered  Aboriginal/Torres Strait Islander  \
# 0             APT-1        Single Room                                No
# 1             APT-3          1-Bedroom                                No
# 2             APT-5         2-Bedroom                                 NaN
# 3         College-1          5-Bedroom                                No
# 4             APT-3        Single Room                                No
#
#   Course Description Enrollment Class      1st Room Preference  \
# 0          Program 1    Undergraduate      Single Room - APT-1
# 1          Program 2     Postgraduate  Two Bedroom - College-1
# 2          Program 3              PhD  One Bedroom - College-3
# 3          Program 2              PhD      Single Room - APT-1
# 4          Program 2     Postgraduate  Two Bedroom - College-5
#
#        2nd Room Preference      3rd Room Preference   Student Type
# 0      Two Bedroom - APT-3     Five Bedroom - APT-3       Domestic
# 1      Single Room - APT-1      Single Room - APT-5  International
# 2  Two Bedroom - College-3      Single Room - APT-1       Domestic
# 3      Single Room - APT-5  One Bedroom - College-3  International
# 4  Two Bedroom - College-5      Single Room - APT-5       Domestic
#
# [5 rows x 23 columns]

# %%
# Replacing buildings' code names with their full names (which are disclosed in the Capacity sheet)
applicant_df1['Location offered'] = applicant_df1['Location offered'].replace({
    'APT-1': 'Amazing Apartment',
    'APT-3': 'Brilliant Apartment',
    'APT-5': 'Fantastic Apartment',
    'College-1': 'Great College',
    'College-3': 'Incredible College',
    'College-5': 'Wonderful College'
})

# See how the data frame looks like (first 5 lines)
applicant_df1.head()
# Out:
#     Age  Entry ID             Gender           City State Province  \
# 0  22.0    400001               Male         City 1     Province 1
# 1  19.0    400002             Female  International  International
# 2  22.0    400003  Prefer not to say         City 3    Province 10
# 3  17.0    400004              Other  International  International
# 4  24.0    400005               Male         City 5     Province 1
#
#    Zip Postcode Application Date Application Status   \
# 0        1234.0       2024-11-01      Offer Accepted
# 1           NaN       2024-11-16      Offer Declined
# 2        2300.0       2023-11-03      Offer Accepted
# 3           NaN       2024-10-05      Offer Declined
# 4        1234.0       2023-01-05      Offer Accepted
#
#   Classification Description Offer Reply Date  ... Partner accompanied?  \
# 0                       New        2024-11-21  ...                False
# 1                   Returner       2024-11-21  ...                False
# 2                       New        2024-11-24  ...                False
# 3                       New        2024-11-30  ...                False
# 4                   Returner       2024-01-24  ...                False
#
#       Location offered  Room Type offered  Aboriginal/Torres Strait Islander  \
# 0    Amazing Apartment        Single Room                                No
# 1  Brilliant Apartment          1-Bedroom                                No
# 2  Fantastic Apartment         2-Bedroom                                 NaN
# 3        Great College          5-Bedroom                                No
# 4  Brilliant Apartment        Single Room                                No
#
#   Course Description Enrollment Class      1st Room Preference  \
# 0          Program 1    Undergraduate      Single Room - APT-1
# 1          Program 2     Postgraduate  Two Bedroom - College-1
# 2          Program 3              PhD  One Bedroom - College-3
# 3          Program 2              PhD      Single Room - APT-1
# 4          Program 2     Postgraduate  Two Bedroom - College-5
#
#        2nd Room Preference      3rd Room Preference   Student Type
# 0      Two Bedroom - APT-3     Five Bedroom - APT-3       Domestic
# 1      Single Room - APT-1      Single Room - APT-5  International
# 2  Two Bedroom - College-3      Single Room - APT-1       Domestic
# 3      Single Room - APT-5  One Bedroom - College-3  International
# 4  Two Bedroom - College-5      Single Room - APT-5       Domestic
#
# [5 rows x 23 columns]

# %%
cols = ['1st Room Preference', '2nd Room Preference','3rd Room Preference']

applicant_df1[cols] = applicant_df1[cols].replace({
    'Single Room - APT-1': 'Single Room - Amazing Apartment',
    'Single Room - APT-3': 'Single Room - Brilliant Apartment',
    'Single Room - APT-5': 'Single Room - Fantastic Apartment',
    'Single Room - College-1': 'Single Room - Great College',
    'Single Room - College-3': 'Single Room - Incredible College',
    'Single Room - College-5': 'Single Room - Wonderful College',
    'One Bedroom - APT-1': '1-Bedroom - Amazing Apartment',
    'One Bedroom - APT-3': '1-Bedroom - Brilliant Apartment',
    'One Bedroom - APT-5': '1-Bedroom - Fantastic Apartment',
    'One Bedroom - College-1': '1-Bedroom - Great College',
    'One Bedroom - College-3': '1-Bedroom - Incredible College',
    'One Bedroom - College-5': '1-Bedroom - Wonderful College',
    'Two Bedroom - APT-1': '2-Bedroom - Amazing Apartment',
    'Two Bedroom - APT-3': '2-Bedroom - Brilliant Apartment',
    'Two Bedroom - APT-5': '2-Bedroom - Fantastic Apartment',
    'Two Bedroom - College-1': '2-Bedroom - Great College',
    'Two Bedroom - College-3': '2-Bedroom - Incredible College',
    'Two Bedroom - College-5': '2-Bedroom - Wonderful College',
    'Five Bedroom - APT-1': '5-Bedroom - Amazing Apartment',
    'Five Bedroom - APT-3': '5-Bedroom - Brilliant Apartment',
    'Five Bedroom - APT-5': '5-Bedroom - Fantastic Apartment',
    'Five Bedroom - College-1': '5-Bedroom - Great College',
    'Five Bedroom - College-3': '5-Bedroom - Incredible College',
    'Five Bedroom - College-5': '5-Bedroom - Wonderful College'
})

# See how the data frame looks like
applicant_df1
# Out:
#      Age  Entry ID             Gender           City State Province  \
# 0   22.0    400001               Male         City 1     Province 1
# 1   19.0    400002             Female  International  International
# 2   22.0    400003  Prefer not to say         City 3    Province 10
# 3   17.0    400004              Other  International  International
# 4   24.0    400005               Male         City 5     Province 1
# 5   24.0    400006  Prefer not to say  International  International
# 6   18.0    400007               Male  International  International
# 7   20.0    400008  Prefer not to say         City 8     Province 2
# 8   20.0    400009  Prefer not to say         City 9     Province 9
# 9   18.0    400010             Female  International  International
# 10  24.0    400011               Male  International  International
# 11  22.0    400012  Prefer not to say        City 12     Province 3
# 12  24.0    400013  Prefer not to say  International  International
# 13  23.0    400014  Prefer not to say        City 14     Province 3
# 14  18.0    400015             Female        City 15  International
# 15  23.0    400016             Female        City 16     Province 3
# 16  22.0    400017             Female  International  International
# 17  20.0    400018  Prefer not to say        City 18     Province 9
# 18  22.0    400019             Female  International  International
# 19  21.0    400020              Other        City 20     Province 9
# 20  21.0    400021              Other  International  International
#
#     Zip Postcode Application Date Application Status   \
# 0         1234.0       2024-11-01      Offer Accepted
# 1            NaN       2024-11-16      Offer Declined
# 2         2300.0       2023-11-03      Offer Accepted
# 3            NaN       2024-10-05      Offer Declined
# 4         1234.0       2023-01-05      Offer Accepted
# 5            NaN       2023-02-02      Offer Declined
# 6         2000.0       2024-03-03      Offer Declined
# 7         1234.0       2024-04-04      Offer Accepted
# 8            NaN       2024-05-05      Offer Accepted
# 9         1234.0       2024-06-06      Offer Accepted
# 10           NaN       2023-07-07      Offer Accepted
# 11        2100.0       2024-08-08      Offer Accepted
# 12           NaN       2023-09-09      Offer Accepted
# 13        1234.0       2024-10-10      Offer Accepted
# 14        1234.0       2023-10-20      Offer Accepted
# 15           NaN       2023-10-29      Offer Declined
# 16           NaN       2023-11-25      Offer Accepted
# 17        1234.0       2024-11-30      Offer Accepted
# 18        1234.0       2023-11-01      Offer Declined
# 19           NaN       2024-12-12      Offer Accepted
# 20           NaN       2023-10-01      Offer Accepted
#
#    Classification Description Offer Reply Date  ... Partner accompanied?  \
# 0                        New        2024-11-21  ...                False
# 1                    Returner       2024-11-21  ...                False
# 2                        New        2024-11-24  ...                False
# 3                        New        2024-11-30  ...                False
# 4                    Returner       2024-01-24  ...                False
# 5                        New        2024-02-13  ...                False
# 6                        New        2024-03-01  ...                False
# 7                        New        2024-03-14  ...                 True
# 8                    Returner       2024-05-30  ...                False
# 9                        New        2024-06-19  ...                False
# 10                   Returner       2024-07-13  ...                 True
# 11                       New        2024-08-20  ...                False
# 12                       New               NaN  ...                 True
# 13                       New        2024-09-21  ...                False
# 14                       New        2023-11-10  ...                 True
# 15                       New        2023-11-17  ...                False
# 16                   Returner       2023-12-12  ...                False
# 17                       New        2023-12-14  ...                False
# 18                       New        2023-11-20  ...                False
# 19                       New               NaN  ...                False
# 20                       New        2023-11-14  ...                False
#
#        Location offered  Room Type offered  Aboriginal/Torres Strait Islander  \
# 0     Amazing Apartment        Single Room                                No
# 1   Brilliant Apartment          1-Bedroom                                No
# 2   Fantastic Apartment         2-Bedroom                                 NaN
# 3         Great College          5-Bedroom                                No
# 4   Brilliant Apartment        Single Room                                No
# 5     Wonderful College          5-Bedroom                                No
# 6     Wonderful College          5-Bedroom                                No
# 7   Fantastic Apartment        Single Room                                No
# 8         Great College          5-Bedroom                                No
# 9   Brilliant Apartment          5-Bedroom                                No
# 10  Fantastic Apartment        Single Room                                No
# 11  Fantastic Apartment        Single Room                                No
# 12  Brilliant Apartment         2-Bedroom                                 No
# 13  Fantastic Apartment          1-Bedroom                                No
# 14  Fantastic Apartment          1-Bedroom                                No
# 15    Wonderful College          5-Bedroom                                Yes
# 16    Amazing Apartment          1-Bedroom                                No
# 17        Great College         2-Bedroom                                 No
# 18    Wonderful College          5-Bedroom                                No
# 19    Amazing Apartment          1-Bedroom                                No
# 20    Amazing Apartment         2-Bedroom                                 No
#
#    Course Description Enrollment Class                1st Room Preference  \
# 0           Program 1    Undergraduate    Single Room - Amazing Apartment
# 1           Program 2     Postgraduate          2-Bedroom - Great College
# 2           Program 3              PhD     1-Bedroom - Incredible College
# 3           Program 2              PhD    Single Room - Amazing Apartment
# 4           Program 2     Postgraduate      2-Bedroom - Wonderful College
# 5           Program 3    Undergraduate    2-Bedroom - Brilliant Apartment
# 6           Program 1     Postgraduate                Single Room - APT 1
# 7           Program 1    Undergraduate  Single Room - Fantastic Apartment
# 8           Program 3    Undergraduate      1-Bedroom - Amazing Apartment
# 9           Program 1    Undergraduate    Single Room - Amazing Apartment
# 10          Program 1    Undergraduate    5-Bedroom - Brilliant Apartment
# 11          Program 3     Postgraduate    Single Room - Amazing Apartment
# 12          Program 1              PhD    5-Bedroom - Fantastic Apartment
# 13          Program 3              PhD    1-Bedroom - Fantastic Apartment
# 14          Program 2              PhD    2-Bedroom - Fantastic Apartment
# 15          Program 3    Undergraduate          1-Bedroom - Great College
# 16          Program 3     Postgraduate    Single Room - Amazing Apartment
# 17          Program 1     Postgraduate      2-Bedroom - Amazing Apartment
# 18          Program 2              PhD    Single Room - Amazing Apartment
# 19          Program 3     Postgraduate      1-Bedroom - Amazing Apartment
# 20          Program 2              PhD    Single Room - Amazing Apartment
#
#                   2nd Room Preference                3rd Room Preference  \
# 0     2-Bedroom - Brilliant Apartment    5-Bedroom - Brilliant Apartment
# 1     Single Room - Amazing Apartment  Single Room - Fantastic Apartment
# 2      2-Bedroom - Incredible College    Single Room - Amazing Apartment
# 3   Single Room - Fantastic Apartment     1-Bedroom - Incredible College
# 4       2-Bedroom - Wonderful College  Single Room - Fantastic Apartment
# 5       2-Bedroom - Amazing Apartment      1-Bedroom - Wonderful College
# 6                 One Bedroom - APT 3  Single Room - Fantastic Apartment
# 7   Single Room - Brilliant Apartment     2-Bedroom - Incredible College
# 8   Single Room - Brilliant Apartment    5-Bedroom - Brilliant Apartment
# 9     1-Bedroom - Fantastic Apartment  Single Room - Fantastic Apartment
# 10      5-Bedroom - Amazing Apartment    5-Bedroom - Fantastic Apartment
# 11  Single Room - Brilliant Apartment  Single Room - Fantastic Apartment
# 12      5-Bedroom - Amazing Apartment    Single Room - Wonderful College
# 13    Single Room - Amazing Apartment  Single Room - Fantastic Apartment
# 14    5-Bedroom - Brilliant Apartment    1-Bedroom - Fantastic Apartment
# 15  Single Room - Brilliant Apartment  Single Room - Fantastic Apartment
# 16      1-Bedroom - Amazing Apartment  Single Room - Fantastic Apartment
# 17    1-Bedroom - Brilliant Apartment    2-Bedroom - Fantastic Apartment
# 18    Single Room - Amazing Apartment    5-Bedroom - Fantastic Apartment
# 19      2-Bedroom - Amazing Apartment  Single Room - Fantastic Apartment
# 20    1-Bedroom - Brilliant Apartment    5-Bedroom - Fantastic Apartment
#
#      Student Type
# 0        Domestic
# 1   International
# 2        Domestic
# 3   International
# 4        Domestic
# 5   International
# 6   International
# 7        Domestic
# 8        Domestic
# 9   International
# 10  International
# 11       Domestic
# 12  International
# 13       Domestic
# 14  International
# 15       Domestic
# 16  International
# 17       Domestic
# 18  International
# 19       Domestic
# 20  International
#
# [21 rows x 23 columns]

# %% [markdown]
# Dataset 2.2 Pricing
#
# Add a column called "Total Monthly Cost", which is the sum of monthly rent and monthly utilities

# %%
pricing_df['Total Monthly Cost'] = (
    pricing_df['Monthly Rent'] + pricing_df['Monthly Utilities']
)

# See how the data frame looks like (first 5 lines)
pricing_df.head()
# Out:
#   Room Building    Room Type  Monthly Rent  Monthly Utilities  \
# 0         APT-1  Single Room          1000                 50
# 1         APT-1    1 Bedroom           950                 50
# 2         APT-1    2 Bedroom           900                 50
# 3         APT-1    5 Bedroom           800                 50
# 4         APT-3  Single Room          2000                100
#
#    Total Monthly Cost
# 0                1050
# 1                1000
# 2                 950
# 3                 850
# 4                2100

# %% [markdown]
# #Step 3. Export the .csv files that have undergone the data-cleaning process using Python, because they will be used in Power BI next to create the dashboard

# %%
from google.colab import files

applicant_df1.to_csv('applicant.csv', index=False)
pricing_df.to_csv('pricing.csv', index=False)

# Download the file
files.download('applicant.csv')
files.download('pricing.csv')
